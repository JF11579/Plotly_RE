# %% [markdown]
# <a href="https://colab.research.google.com/github/JF11579/Plotly_RE/blob/main/SameHouse/Report_SameHouse_Feb16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notes
#
# ### To supress code place this in the cell.
# # @hidden_cell

# %% [markdown]
# # Libraries

# %%
import pandas as pd
from google.colab import drive  # <<<<<<<<<------
import plotly.express as px
import numpy as np
import plotly.graph_objects as go

# %% [markdown]
# # Options

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Data

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Change to the directory containing your CSV
# %cd /content/drive/MyDrive/DATA/Real_Estate_Data
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/DATA/Real_Estate_Data

# %%
data = pd.read_csv('Combined_data_Jan_10_3.csv')

data.head(3)
# Out:
# <ipython-input-29-3a02a300e0fc>:1: DtypeWarning:
#
# Columns (5,17,19,21,22,23,24,26,28,29,32,33,35,36,37,41,43,45,46,47,48,49,51,54,55,56,57,59,60,62,72,73,74,76,85,86,89,90,104,107,109,111,113,115,117,123,124,125,127,135,143,144,151,152,154,156,158,160,161,164,167,174,180,181,184,185,187,188,189,190,191,192,193,194,199,200,202,203,208,214,216,217,220) have mixed types. Specify dtype option on import or set low_memory=False.
#                Address           Town    Zip State     Style      ML#  \
# 0      19 Winans Place  Locust Valley  11560    NY      Cape  1870802
# 1       59 11th Street  Locust Valley  11560    NY  Colonial  2745482
# 2  19 White Spots Lane  Locust Valley  11560    NY  Exp Cape  2427641
#
#    Sold_Price  Baths_Full  Baths_Half  Bath  Bedrooms Appearance  REO  \
# 0    459000.0         2.0         0.0   2.0       4.0  Excellent  NaN
# 1    360000.0         2.0         0.0   2.0       4.0       Good    N
# 2    650000.0         2.0         1.0   2.5       3.0       Mint    N
#
#   School_District_Name  Approx_Int_Square_Footage  Street_Name Contract_Date  \
# 0        Locust Valley                        NaN       Winans     9/14/2006
# 1        Locust Valley                        NaN         11th    11/23/2015
# 2        Locust Valley                     2353.0  White Spots    10/08/2011
#
#   Contract Date    Year Air_Conditioning  Acres Property_Description Agency  \
# 0    2006-09-14  2006.0              NaN    NaN                  NaN    NaN
# 1    2015-11-23  2015.0              NaN    NaN                  NaN    NaN
# 2    2011-10-08  2011.0              NaN    NaN                  NaN    NaN
#
#   Also_For_Rent Interior_Features  Apt# Attic_Description  Auxiliary_Rooms  \
# 0           NaN               NaN   NaN               NaN              NaN
# 1           NaN               NaN   NaN               NaN              NaN
# 2           NaN               NaN   NaN               NaN              NaN
#
#   Buyer_Agency_Compensation Waterfront_Features  Building  Building_Permit  \
# 0                       NaN                 NaN       NaN              NaN
# 1                       NaN                 NaN       NaN              NaN
# 2                       NaN                 NaN       NaN              NaN
#
#   Block Listing_Broker_Phone_#  Branch Modifications_Exclusions  \
# 0   NaN                    NaN     NaN                      NaN
# 1   NaN                    NaN     NaN                      NaN
# 2   NaN                    NaN     NaN                      NaN
#
#   Basement_Description Room_Level  Business_Age  Business_Type  \
# 0                  NaN        NaN           NaN            NaN
# 1                  NaN        NaN           NaN            NaN
# 2                  NaN        NaN           NaN            NaN
#
#    Utilities_Included Included  Cash_Down Contract_Cancel_Effective_Date  \
# 0                 NaN      NaN        NaN                            NaN
# 1                 NaN      NaN        NaN                            NaN
# 2                 NaN      NaN        NaN                            NaN
#
#    Under_Steel Available_Utilities Class_Description Co-Listing_Agent  \
# 0          NaN                 NaN               NaN              NaN
# 1          NaN                 NaN               NaN              NaN
# 2          NaN                 NaN               NaN              NaN
#
#   Co-Listing_Agent2 Broker_Code  Common_Charges Commission_Oblig_Date  \
# 0               NaN         NaN             NaN                   NaN
# 1               NaN         NaN             NaN                   NaN
# 2               NaN         NaN             NaN                   NaN
#
#    Compensation_Paid_By  Compass_Points W/R_Conditions  \
# 0                   NaN             NaN            NaN
# 1                   NaN             NaN            NaN
# 2                   NaN             NaN            NaN
#
#   Construction_Description Lot_Description County  Contract_Price  \
# 0                      NaN             NaN    NaN             NaN
# 1                      NaN             NaN    NaN             NaN
# 2                      NaN             NaN    NaN             NaN
#
#   Cross_Street Location_Features  DBA Exterior_Features  Deductible_%  \
# 0          NaN               NaN  NaN               NaN           NaN
# 1          NaN               NaN  NaN               NaN           NaN
# 2          NaN               NaN  NaN               NaN           NaN
#
#    Income_Desc_1  Income_Desc_2  Income_Desc_3  Income_Desc_4  Income_Desc_5  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
#
#    Income_Desc_6  Income_Desc_7  Income_Desc_8 Detached/Attached Development  \
# 0            NaN            NaN            NaN               NaN         NaN
# 1            NaN            NaN            NaN               NaN         NaN
# 2            NaN            NaN            NaN               NaN         NaN
#
#   District  Days_On_Market Driveway  Fees  Finance_Restrictions  \
# 0      NaN             NaN      NaN   NaN                   NaN
# 1      NaN             NaN      NaN   NaN                   NaN
# 2      NaN             NaN      NaN   NaN                   NaN
#
#    Final_Mortgage  Fixtures_&_Equipment  Floor_Load  #_Fireplaces  \
# 0             NaN                   NaN         NaN           NaN
# 1             NaN                   NaN         NaN           NaN
# 2             NaN                   NaN         NaN           NaN
#
#    Frontage_Feet  Feet_From_Corner Heating_Fuel Parking  LandLord_Pays  \
# 0            NaN               NaN          NaN     NaN            NaN
# 1            NaN               NaN          NaN     NaN            NaN
# 2            NaN               NaN          NaN     NaN            NaN
#
#    Gross_Profit_% Building_Features Heating_Type  Hilp$  Inc_1_$  Inc_2_$  \
# 0             NaN               NaN          NaN    NaN      NaN      NaN
# 1             NaN               NaN          NaN    NaN      NaN      NaN
# 2             NaN               NaN          NaN    NaN      NaN      NaN
#
#    Inc_3_$  Inc_4_$  Inc_5_$  Inc_6_$  Inc_7_$  Inc_8_$  Inventory_Included  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN                 NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN                 NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN                 NaN
#
#    Insurance  Distribute_To_Internet_Portals  Inventory Listing_Date  Lease  \
# 0        NaN                             NaN        NaN          NaN    NaN
# 1        NaN                             NaN        NaN          NaN    NaN
# 2        NaN                             NaN        NaN          NaN    NaN
#
#    Topography Listing_Agent  Number_of_Docks Lockbox  Lolp$  Lot  \
# 0         NaN           NaN              NaN     NaN    NaN  NaN
# 1         NaN           NaN              NaN     NaN    NaN  NaN
# 2         NaN           NaN              NaN     NaN    NaN  NaN
#
#    Lot_Square_Footage Lot_Size  Listing_Price Last_Status_Change  Lease_Years  \
# 0                 NaN      NaN            NaN                NaN          NaN
# 1                 NaN      NaN            NaN                NaN          NaN
# 2                 NaN      NaN            NaN                NaN          NaN
#
#   Last_Update_Date  Maintenance  Maintenance/Repairs_Expense  \
# 0              NaN          NaN                          NaN
# 1              NaN          NaN                          NaN
# 2              NaN          NaN                          NaN
#
#    Minimum_Plot_Size  Miscellaneous_Expense  Model_Name Moved_From  \
# 0                NaN                    NaN         NaN        NaN
# 1                NaN                    NaN         NaN        NaN
# 2                NaN                    NaN         NaN        NaN
#
#   Mortgage_Type Negotiate_Direct  Net_Income New_Construction  #_Families  \
# 0           NaN              NaN         NaN              NaN         NaN
# 1           NaN              NaN         NaN              NaN         NaN
# 2           NaN              NaN         NaN              NaN         NaN
#
#    #_Floors_In_Building  #_Floors_In_Unit  #_Kitchens  #_Plots  #_Units  \
# 0                   NaN               NaN         NaN      NaN      NaN
# 1                   NaN               NaN         NaN      NaN      NaN
# 2                   NaN               NaN         NaN      NaN      NaN
#
#    #_Heating_Zones Occupancy  Office_%  Broker_Open_House_Description  \
# 0              NaN       NaN       NaN                            NaN
# 1              NaN       NaN       NaN                            NaN
# 2              NaN       NaN       NaN                            NaN
#
#    Broker_Open_Houses  Lease_Conditions  Original_Price  Other_Fees  \
# 0                 NaN               NaN             NaN         NaN
# 1                 NaN               NaN             NaN         NaN
# 2                 NaN               NaN             NaN         NaN
#
#    Out_of_Area_Town Owner Owner_Financing  Parking_Charges  \
# 0               NaN   NaN             NaN              NaN
# 1               NaN   NaN             NaN              NaN
# 2               NaN   NaN             NaN              NaN
#
#    Parking_Facilities  Parking_Spaces  Parking_Spaces_At_Building  \
# 0                 NaN             NaN                         NaN
# 1                 NaN             NaN                         NaN
# 2                 NaN             NaN                         NaN
#
#    Payroll_Expense  %_Difference Permit Personal_Property_Exclusion  \
# 0              NaN           NaN    NaN                         NaN
# 1              NaN           NaN    NaN                         NaN
# 2              NaN           NaN    NaN                         NaN
#
#    Pets_Allowed Status/Showing_Phone  Planning_Board_Approved  \
# 0           NaN                  NaN                      NaN
# 1           NaN                  NaN                      NaN
# 2           NaN                  NaN                      NaN
#
#   Pool_Description  Possible_Subdivision Price_Range_Listing  Property_Type  \
# 0              NaN                   NaN                 NaN            NaN
# 1              NaN                   NaN                 NaN            NaN
# 2              NaN                   NaN                 NaN            NaN
#
#   Proposed_Title_Date Purchaser  Renting_Broker_Branch  Renting_Broker_Code  \
# 0                 NaN       NaN                    NaN                  NaN
# 1                 NaN       NaN                    NaN                  NaN
# 2                 NaN       NaN                    NaN                  NaN
#
#   Renting_Broker_Compensation  Rented_Date  Road_Surface Remarks  \
# 0                         NaN          NaN           NaN     NaN
# 1                         NaN          NaN           NaN     NaN
# 2                         NaN          NaN           NaN     NaN
#
#    Rent_Expense  Renting_Agent  Rent_Income  Rent_Per_Square_Foot  \
# 0           NaN            NaN          NaN                   NaN
# 1           NaN            NaN          NaN                   NaN
# 2           NaN            NaN          NaN                   NaN
#
#    Rental_Type  Relist_Obligation_Date Listing_Broker  Rooms  Rented_Price  \
# 0          NaN                     NaN            NaN    NaN           NaN
# 1          NaN                     NaN            NaN    NaN           NaN
# 2          NaN                     NaN            NaN    NaN           NaN
#
#    Renting_Broker  Sale_or_Rent  Selling_Broker_Branch Selling_Broker_Code  \
# 0             NaN           NaN                    NaN                 NaN
# 1             NaN           NaN                    NaN                 NaN
# 2             NaN           NaN                    NaN                 NaN
#
#   Seller_Agency_Compensation  School_District_#  Seats Section Section/Area  \
# 0                        NaN                NaN    NaN     NaN          NaN
# 1                        NaN                NaN    NaN     NaN          NaN
# 2                        NaN                NaN    NaN     NaN          NaN
#
#    Security_Deposit Selling_Agent Separate_Hotwater_Heater Show_Instructions  \
# 0               NaN           NaN                      NaN               NaN
# 1               NaN           NaN                      NaN               NaN
# 2               NaN           NaN                      NaN               NaN
#
#   Selling_Broker Street_Direction Street_Number Street_Suffix Status  Stories  \
# 0            NaN              NaN           NaN           NaN    NaN      NaN
# 1            NaN              NaN           NaN           NaN    NaN      NaN
# 2            NaN              NaN           NaN           NaN    NaN      NaN
#
#    Supercedes_ML#  Taxes  Taxes_W/Star_Exemption Title_Date  TOM  Terms  \
# 0             NaN    NaN                     NaN        NaN  NaN    NaN
# 1             NaN    NaN                     NaN        NaN  NaN    NaN
# 2             NaN    NaN                     NaN        NaN  NaN    NaN
#
#   TOM_Start_Date TOM_End_Date  Total_Expenses  Total_Income  Type_Ownership  \
# 0            NaN          NaN             NaN           NaN             NaN
# 1            NaN          NaN             NaN           NaN             NaN
# 2            NaN          NaN             NaN           NaN             NaN
#
#    Type_Sale Unit_#  Unit_on_Floor_#  Vacancy_%  Development_Status  \
# 0        NaN    NaN              NaN        NaN                 NaN
# 1        NaN    NaN              NaN        NaN                 NaN
# 2        NaN    NaN              NaN        NaN                 NaN
#
#    Village_Taxes  Water_Frontage Water_Description  Wooded/Cleared  \
# 0            NaN             NaN               NaN             NaN
# 1            NaN             NaN               NaN             NaN
# 2            NaN             NaN               NaN             NaN
#
#   Withdrawn/Release_Date Exp_Date  Year_Built  Zone Zoning
# 0                    NaN      NaN         NaN   NaN    NaN
# 1                    NaN      NaN         NaN   NaN    NaN
# 2                    NaN      NaN         NaN   NaN    NaN

# %%
median_cat_data = pd.read_csv('median_category_data.csv')

median_cat_data.head(3)
# Out:
#             Town  Median_Sold Median_Category
# 0  New Hyde Park       800000    Above Median
# 1       Bethpage       650000    Below Median
# 2       Levitown       612000    Below Median

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Change to the directory containing your CSV
# %cd /content/drive/MyDrive/DATA/Population_and_Political_Data
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/DATA/Population_and_Political_Data

# %%
mean_incomnes =  pd.read_csv('Avg_and_Median_Incomes_9_towns - Sheet1 (1).csv')

# %% [markdown]
# # Pre Processing

# %%
data = data.dropna(subset=["Sold_Price"]).query("`Sold_Price` != 0")
data = data[['Address', 'Town','Zip','State','Style',
                    'ML#','Sold_Price','Baths_Full', 'Baths_Half',
                    'Bath','Bedrooms',
                      'Appearance','REO' , 'School_District_Name',
                 'Approx_Int_Square_Footage','Street_Name','Contract_Date']]
data= data.loc[data.Town.isin(['Roosevelt', 'Hempstead', 'Freeport', 'Farmingdale', 'Mineola','Westbury', 'Roslyns', 'Port Washington', 'Locust Valley'])]
# Convert 'Contract_Date' to datetime
data['Contract_Date'] = pd.to_datetime(data['Contract_Date'])

# Extract the year
data['Year'] = data['Contract_Date'].dt.year


# Drop rows where 'Year' is NaN
data = data.dropna(subset=['Year'])

# Now convert 'Year' to integer
data['Year'] = data['Year'].astype(int)
# Out:
# <ipython-input-33-ea41c15f3b3f>:19: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
median_sold_price_all = data.groupby(['Town', 'Year'])['Sold_Price'].median().reset_index()
median_sold_price_all.rename(columns={'Sold_Price': 'Median_Sold_Price_All'}, inplace=True)

# %%
# Merge Median_Sold_Price_All
data = data.merge(median_sold_price_all, on=['Town', 'Year'], how='left')

# %% [markdown]
# ## Consolidate House Style

# %%
# Calculate the frequency of each style
style_counts = data['Style'].value_counts(normalize=True) * 100

# Identify styles that are less than 5%
styles_to_replace = style_counts[style_counts < 5].index
#
# Replace styles that are less than 5% with 'Other'
data['Style'] = data['Style'].replace(styles_to_replace, 'Other')

# %% [markdown]
# # Discussions of real esatate speak of it as if were a homgenous thing.  Bus as we will see the more one drills down the less homogenous real estate is

# %% [markdown]
# ##Consolidate the 3 Roslynbns in Roslyns

# %%
import pandas as pd

# Read the CSV file into a DataFrame
#med_incomes = pd.read_csv('Median_Incomes_9_towns.csv')
mean_incomnes =  pd.read_csv('Avg_and_Median_Incomes_9_towns - Sheet1 (1).csv')

# Define the towns to combine
roslyn_towns = ['Roslyn_Harbor', 'Roslyn', 'Roslyn_Heights']

# Create a copy of the DataFrame to avoid modifying the original
combined_data = mean_incomnes.copy()

# Combine rows with Roslyn town names
combined_data.loc[combined_data['Town'].isin(roslyn_towns), 'Town'] = 'Roslyns'

# Group data by Year and Town, calculate average household income
average_income_per_town_year = combined_data.groupby(['Year', 'Town'])['Mean_Income'].mean().reset_index()

# Update the original DataFrame with the combined data
mean_incomnes = average_income_per_town_year

# Print the updated DataFrame
print(mean_incomnes)
# Out:
#     Year             Town    Mean_Income
# 0   2000      Farmingdale   72506.000000
# 1   2000         Freeport   66755.000000
# 2   2000        Hempstead   59213.000000
# 3   2000    Locust_Valley   96067.000000
# 4   2000          Mineola   74195.000000
# 5   2000  Port_Washington  122357.000000
# 6   2000        Roosevelt   61758.000000
# 7   2000          Roslyns  131770.000000
# 8   2000         Westbury   83826.000000
# 9   2010      Farmingdale   99253.000000
# 10  2010         Freeport   86662.000000
# 11  2010        Hempstead   64221.000000
# 12  2010    Locust_Valley  110743.000000
# 13  2010          Mineola   90171.000000
# 14  2010  Port_Washington  155366.000000
# 15  2010        Roosevelt   78509.000000
# 16  2010          Roslyns  192091.666667
# 17  2010         Westbury   98377.000000
# 18  2020      Farmingdale  138851.000000
# 19  2020         Freeport  108102.000000
# 20  2020        Hempstead   91477.000000
# 21  2020    Locust_Valley  226535.000000
# 22  2020          Mineola  124774.000000
# 23  2020  Port_Washington  217492.000000
# 24  2020        Roosevelt  109155.000000
# 25  2020          Roslyns  214591.000000
# 26  2020         Westbury  140533.000000

# %%
# prompt: convert  Household_Income to integer

mean_incomnes['Mean_Income'] = mean_incomnes['Mean_Income'].astype(int)

# %% [markdown]
# ## Plot General Slope

# %%
import pandas as pd
import plotly.graph_objects as go

slope_data = data

# Assuming 'data' is your DataFrame

# Filter the data for the years you are interested in, if needed
years_of_interest = [2006, 2023]  # Example years
data_filtered = slope_data[slope_data['Year'].isin(years_of_interest)]

# Calculate overall median sold price for 2006 and 2023
overall_median_prices = data_filtered.groupby('Year')['Sold_Price'].median().reset_index()

# Creating the slope graph
fig = go.Figure()

# Add a line for the overall median sold prices
fig.add_trace(go.Scatter(x=overall_median_prices['Year'], y=overall_median_prices['Sold_Price'],
                         mode='lines+markers', name='Overall Median Sold Price'))

# Add a line for the overall median sold prices with increased line thickness
fig.add_trace(go.Scatter(
    x=overall_median_prices['Year'],
    y=overall_median_prices['Sold_Price'],
    mode='lines+markers',
    name='Overall Median Sold Price',
    line=dict(width=6)  # Increase the line width here
))

# Update layout to match Economist style (omitted for brevity)

# Update the figure to exclude 'Overall Median Sold Price' from the legend
fig.update_traces(selector=dict(name="Overall Median Sold Price"), showlegend=False)

##############################################
#################. ECONOMIST STYLE. #########
# Define Economist-style colors and fonts
economist_red = '#e3120b'  # The Economist's signature red color
background_color = 'rgb(195, 215, 227)'  # The specified background color
font_family = "Arial, sans-serif"  # A commonly used font similar to those in publications

# Customize the plot
fig.update_layout(
    title={'text': "Median Sold Prices by Style in Each Town", 'y':0.9, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
    title_font=dict(size=18, color=economist_red, family=font_family),
    plot_bgcolor=background_color,
    paper_bgcolor=background_color,
    font=dict(color='black', family=font_family),
    xaxis_title="",
    yaxis_title="",
    legend_title="",
    xaxis=dict(showline=True, showgrid=False, linecolor='black'),
    yaxis=dict(showline=True, showgrid=True, gridcolor='lightgrey', linecolor='black')
)
#########################################################
##########################################################

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2213462d-aa46-432c-b143-4e16b9b842be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2213462d-aa46-432c-b143-4e16b9b842be")) {                    Plotly.newPlot(                        "2213462d-aa46-432c-b143-4e16b9b842be",                        [{"mode":"lines+markers","name":"Overall Median Sold Price","x":[2006,2023],"y":[447595.0,655000.0],"type":"scatter","showlegend":false},{"line":{"width":6},"mode":"lines+markers","name":"Overall Median Sold Price","x":[2006,2023],"y":[447595.0,655000.0],"type":"scatter","showlegend":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth": ...

# %% [markdown]
# # But now let us drill down and disaggregate that line.  Notice there are three color groups but the lines themselves are in only two groups?

# %% [markdown]
# # Reuseabble code

# %% [markdown]
# ## Town color dictionary

# %%
# # Define your color dictionary
# color_dict = {
#     'Roslyn': 'darkgreen',
#     'Port Washington': 'green',
#     'Locust Valley': 'lightgreen',
#     'Mineola': 'darkblue',
#     'Westbury': 'blue',
#     'Farmingdale': 'lightblue',
#     'Freeport': 'darkred',
#     'Hempstead': 'red',
#     'Roosevelt': 'lightred'
# }

# or

# color_dict = {
#     'Roslyns': '#006400',  # DarkGreen
#     'Port Washington': '#008000',  # Green
#     'Locust Valley': '#90EE90',  # LightGreen
#     'Mineola': '#00008B',  # DarkBlue
#     'Westbury': '#0000FF',  # Blue
#     'Farmingdale': '#ADD8E6',  # LightBlue
#     'Freeport': '#8B0000',  # DarkRed
#     'Hempstead': '#FF0000',  # Red
#     'Roosevelt': '#F08080'  # LightCoral, close to "light red"
# }

# %% [markdown]
# ## Dollar Styling

# %%
# def format_y_axis_dollar(fig):
#     """
#     Format the y-axis of a Plotly figure to display values in dollar format.

#     Parameters:
#     - fig: The Plotly figure to which the formatting will be applied.
#     """
#     fig.update_layout(yaxis=dict(tickprefix="$", ticksuffix="", tickformat=","))
#     return fig

# %% [markdown]
# # Disaggregated Towns.  LEt us look at the same towns that comprise that aggreagate line above

# %%
import pandas as pd
import plotly.graph_objects as go

disagregated = data

# Assuming 'data' is your DataFrame with columns 'Year', 'Town', and 'Sold_Price'

# Define your color dictionary
color_dict = {
    'Roslyns': '#006400',  # DarkGreen
    'Port Washington': '#008000',  # Green
    'Locust Valley': '#808000',  # oliveGreen #808000
    'Mineola': '#00008B',  # DarkBlue
    'Westbury': '#0000FF',  # Blue
    'Farmingdale': '#40e0d0',  # LightBlue:#ADD8E6 torqoise  #40e0d0
    'Freeport': '#8B0000',  # DarkRed
    'Hempstead': '#FF0000',  # Red
    'Roosevelt': '#F08080'  # LightCoral, close to "light red"
}

# Filter the data for the years you are interested in
years_of_interest = [2006, 2023]  # Adjust to include 2024 if that was your intention
data_filtered = data[data['Year'].isin(years_of_interest)]

# Creating the slope graph
fig = go.Figure()

# Calculate median sold price for each town and year, and add a line for each town
for town, color in color_dict.items():
    df_filtered = data_filtered[data_filtered['Town'] == town]
    median_prices = df_filtered.groupby('Year')['Sold_Price'].median().reset_index()

    fig.add_trace(go.Scatter(x=median_prices['Year'], y=median_prices['Sold_Price'],
                             mode='lines+markers', name=town, line=dict(color=color)))

# Update layout for x-axis and y-axis as requested
fig.update_layout(
    title='Change in Median Sold Price by Town (2006 vs 2023)',  # Update as needed
    xaxis=dict(
        tickmode='array',
        tickvals=[2006, 2023],  # Update to [2006, 2024] if your data includes 2024
        title='Year',
        showline=True,
        showgrid=False,
        linecolor='black'
    ),
    yaxis=dict(
        tickformat='$,.2f',  # Format as dollars
        title='Median Sold Price',
        showline=True,
        showgrid=True,
        gridcolor='lightgrey',
        linecolor='black'
    ),
    legend_title="Town",
    plot_bgcolor='rgb(195, 215, 227)',
    paper_bgcolor='rgb(195, 215, 227)',
    font=dict(color='black', family="Arial, sans-serif")
)


##############################################
#################. ECONOMIST STYLE. #########
# Define Economist-style colors and fonts
economist_red = '#e3120b'  # The Economist's signature red color
background_color = 'rgb(195, 215, 227)'  # The specified background color
font_family = "Arial, sans-serif"  # A commonly used font similar to those in publications

# Customize the plot
fig.update_layout(
    title={'text': "Median Sold Prices by Style in Each Town", 'y':0.9, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
    title_font=dict(size=18, color=economist_red, family=font_family),
    plot_bgcolor=background_color,
    paper_bgcolor=background_color,
    font=dict(color='black', family=font_family),
    xaxis_title="",
    yaxis_title="",
    legend_title="",
    xaxis=dict(showline=True, showgrid=False, linecolor='black'),
    yaxis=dict(showline=True, showgrid=True, gridcolor='lightgrey', linecolor='black')
)
#########################################################
##########################################################
# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="682a91a3-39e7-427f-90f8-8107733c6fb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("682a91a3-39e7-427f-90f8-8107733c6fb7")) {                    Plotly.newPlot(                        "682a91a3-39e7-427f-90f8-8107733c6fb7",                        [{"line":{"color":"#006400"},"mode":"lines+markers","name":"Roslyns","x":[2006,2023],"y":[899500.0,1377500.0],"type":"scatter"},{"line":{"color":"#008000"},"mode":"lines+markers","name":"Port Washington","x":[2006,2023],"y":[735000.0,1082500.0],"type":"scatter"},{"line":{"color":"#808000"},"mode":"lines+markers","name":"Locust Valley","x":[2006,2023],"y":[609500.0,950000.0],"type":"scatter"},{"line":{"color":"#00008B"},"mode":"lines+markers","name":"Mineola","x":[2006,2023],"y":[500000.0,700000.0],"type":"scatter"},{"line":{"color":"#0000FF"},"mode":"lines+markers","name":"Westbury","x":[2006,2023],"y":[459499.5,695000.0],"type":"scatter"},{"line":{"color":"#40e0d0"},"mode":"lines+markers","name":"Farmingdale","x":[2006,2023],"y":[439250.0,630000.0],"type":"scatter"},{"line":{"color":"#8B0000"},"mode":"lines+markers","name":"Freeport","x":[2006,2023],"y":[414000.0,575000.0],"type":"scatter"},{"line":{"color":"#FF0000"},"mode":"lines+markers","name":"Hempstead","x":[2006,2023],"y":[398000.0,557000.0],"type":"scatter"},{"line":{"color":"#F08080"},"mode":"lines+markers","name":"Roosevelt","x":[2006,2023],"y":[361460.0,550000.0],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444 ...

# %% [markdown]
# # And if we drill down yet another layer to within the towns we see still greater variety.

# %%
data3 = data

import plotly.express as px

# Assuming 'data' is your DataFrame

# Filter data for 2006 and 2023
data_filtered = data3[data3['Year'].isin([2006, 2023])]

# Sorting towns by Median_Sold_Price_All in ascending order before grouping
sorted_towns = data_filtered.sort_values(by='Median_Sold_Price_All')['Town'].unique()

# Group by Town, Style, and Year, and calculate median Sold Price
town_style_median_prices = data_filtered.groupby(['Town', 'Style', 'Year'])['Sold_Price'].median().reset_index()

# Creating the faceted plot with sorted towns
fig = px.line(town_style_median_prices, x='Year', y='Sold_Price', color='Style', facet_col='Town',
              category_orders={'Town': sorted_towns},
              facet_col_wrap=9, # Adjust this to control the number of columns
              title='Change in Median Sold Price by House Style and Town (2006 vs. 2023)')

# Update layout for each subplot
for axis in fig.layout:
    if axis.startswith('xaxis') or axis.startswith('yaxis'):
        fig.layout[axis].showline = True
        fig.layout[axis].showgrid = True
        fig.layout[axis].gridcolor = 'white'
        fig.layout[axis].linecolor = 'black'

############ ECONOMIST ##########################
# Define Economist-style colors and fonts
economist_red = '#e3120b'  # The Economist's signature red color
background_color = 'rgb(195, 215, 227)'  # The specified background color
font_family = "Arial, sans-serif"  # A commonly used font similar to those in publications

# Customize the plot
fig.update_layout(
    title={'text': "Median Sold Prices by Style in Each Town", 'y':0.9, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
    title_font=dict(size=18, color=economist_red, family=font_family),
    plot_bgcolor=background_color,
    paper_bgcolor=background_color,
    font=dict(color='black', family=font_family),
    legend_title="House Styles"
)
#########################################################################################

# Adjusting subplot titles and removing "Town="
for a in fig.layout.annotations:
    a.text = a.text.replace('Town=', '')

# Remove the word "Year" from x-axis titles
fig.for_each_xaxis(lambda xaxis: xaxis.update(title=''))

# Remove the x-axis tick labels
fig.for_each_xaxis(lambda xaxis: xaxis.update(tickvals=[]))

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="be8193f6-68f8-4f02-84e4-e2b9db0e9b12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be8193f6-68f8-4f02-84e4-e2b9db0e9b12")) {                    Plotly.newPlot(                        "be8193f6-68f8-4f02-84e4-e2b9db0e9b12",                        [{"hovertemplate":"Style=Cape\u003cbr\u003eTown=Roosevelt\u003cbr\u003eYear=%{x}\u003cbr\u003eSold_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cape","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Cape","orientation":"v","showlegend":true,"x":[2006,2023],"xaxis":"x","y":[350000.0,530000.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Style=Cape\u003cbr\u003eTown=Hempstead\u003cbr\u003eYear=%{x}\u003cbr\u003eSold_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cape","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Cape","orientation":"v","showlegend":false,"x":[2006,2023],"xaxis":"x2","y":[387000.0,525000.0],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Style=Cape\u003cbr\u003eTown=Freeport\u003cbr\u003eYear=%{x}\u003cbr\u003eSold_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cape","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Cape","orientation":"v","showlegend":false,"x":[2006,2023],"xaxis":"x3","y":[386950.0,550000.0],"yaxis":"y3","type":"scatter"},{"hovertemplate":"Style=Cape\u003cbr\u003eTown=Farmingdale\u003cbr\u003eYear=%{x}\u003cbr\u003eSold_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cape","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Cape","orientation":"v","showlegend":false,"x":[2006,2023],"xaxis":"x4","y":[425000.0,590500.0],"yaxis":"y4","type":"scatter"},{"hovertemplate":"Style=Cape\u003cbr\u003eTown=Westbury\u003cbr\u003eYear=%{x}\u003cbr\u003eSold_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cape","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Cape","orientation":"v","showlegend":false,"x":[2006,2023],"xaxis":"x5","y":[424900.0,562500.0],"yaxis":"y5","type":"scatter"},{"hovertemplate":"Style=Cape\u003cbr\u003eTown=Mineola\u003cbr\u003eYear=%{x}\u003cbr\u003eSold_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cape","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Cape","orientation":"v","showlegend":false,"x":[2006,2023],"xaxis":"x6","y":[490000.0,680000.0],"yaxis":"y6","type":"scatter"},{"hovertemplate":"Style=Cape\u003cbr\u003eTown=Locust Valley\u003cbr\u003eYear=%{x}\u003cbr\u003eSold_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cape","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Cape","orientation":"v","showlegend":false,"x":[2006,2023],"xaxis":"x7","y":[580000.0,1020000.0],"yaxis":"y7","type":"scatter"},{"hovertemplate":"Style=Cape\u003cbr\u003eTown=Port Washington\u003cbr\u003eYear=%{x}\u003cbr\u003eSold_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cape","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Cape","orientation":"v","showlegend":false,"x":[2006,2023],"xaxis":"x8","y":[580000.0,599000.0],"yaxis":"y8","type":"scatter"},{"hovertemplate":"Style=Cape\u003cbr\u003eTown=Roslyns\u003cbr\u003eYear=%{x}\u003cbr\u003eSold_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cape","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Cape","orientation":"v","showle ...

# %% [markdown]
# # How did we slect the 9 towns that we did?

# %%
median_cat_data.head()
# Out:
#             Town  Median_Sold Median_Category
# 0  New Hyde Park       800000    Above Median
# 1       Bethpage       650000    Below Median
# 2       Levitown       612000    Below Median
# 3        Mineola       700000          Median
# 4     Great Neck      1400000    Above Median

# %% [markdown]
# # Here is a look while not at every Town in Nassau County, NY  at many.  In Nasau  in 2023 the median price was 710,000.  We are calling median any home that is  +/- $50,000 of that.
#
# # We proceed as if Nassau had 3 housing tiers but that is a stretch.  There is not much diffeence between the lower tier and the middle tier as there is compared to the middle tier to the upper tier.

# %%
def format_y_axis_dollar(fig):
    """
    Format the y-axis of a Plotly figure to display values in dollar format.

    Parameters:
    - fig: The Plotly figure to which the formatting will be applied.
    """
    fig.update_layout(yaxis=dict(tickprefix="$", ticksuffix="", tickformat=","))
    return fig


import plotly.express as px
import pandas as pd

# Assuming this is your provided data
town_data = {
    'Town': ['New Hyde Park', 'Bethpage', 'Levitown', 'Mineola', 'Great Neck', 'Roslyns',
             'Port Washington', 'East Meadow', 'Westbury', 'Hicksville', 'Freeport',
             'Hempstead', 'Uniondale', 'Roosevelt', 'Baldwin', 'Floral Park',
             'East Rockaway', 'Farmingdale', 'Locust Valley', 'Oyster Bay Cove', 'Sands Point'],
    'Median_Sold': [800000, 650000, 612000, 700000, 1400000, 1300000, 1100000, 710000,
                    715000, 659000, 565000, 560000, 582000, 554000, 608000, 765000,
                    579000, 680000, 950000, 2000000, 2446000],
    'Median_Category': ['Above Median', 'Below Median', 'Below Median', 'Median', 'Above Median',
                        'Above Median', 'Above Median', 'Median', 'Median', 'Below Median',
                        'Below Median', 'Below Median', 'Below Median', 'Below Median',
                        'Below Median', 'Above Median', 'Below Median', 'Median', 'Above Median',
                        'Above Median', 'Above Median']
}

median_category_data = pd.DataFrame(town_data)

# Sort data by 'Median_Sold' in ascending order
sorted_data = median_category_data.sort_values(by='Median_Sold', ascending=True)

# Define color map
color_map = {'Above Median': 'green', 'Median': 'blue', 'Below Median': 'red'}

# Create the bar chart
bars = px.bar(sorted_data,
              x='Town',
              y='Median_Sold',
              color='Median_Category',
              color_discrete_map=color_map,
              labels={'Median_Category': 'Category'})

# Add a horizontal line at y=710000
bars.add_hline(y=710000, line_dash="solid", line_color="black", annotation_text="Benchmark", annotation_position="bottom right")

# Add a shaded area for the range ±50000 from 710000
start_x = -0.5  # Starting just before the first bar
end_x = len(sorted_data['Town']) - 0.5  # Ending just after the last bar

bars.add_shape(type="rect",
               x0=start_x, y0=660000, x1=end_x, y1=760000,
               line=dict(width=0),
               fillcolor="gray", opacity=0.5)

# Add an annotation with an arrow
bars.add_annotation(x=len(sorted_data['Town'])/2, y=710000,
                    text="Median Sale Price $710k",
                    showarrow=True,
                    arrowhead=1,
                    arrowsize=2,
                    arrowwidth=2,
                    arrowcolor="black",
                    ax=-50,
                    ay=-50)

############## Economist-style theming. ###################
economist_red = '#e3120b'
background_color = 'rgb(195, 215, 227)'
font_family = "Arial, sans-serif"

# Customize the plot with Economist styling
bars.update_layout(
    title={'text': "Median Sold Price Nassau County, NY 2023", 'y':0.9, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
    title_font=dict(size=18, color=economist_red, family=font_family),
    plot_bgcolor=background_color,
    paper_bgcolor=background_color,
    font=dict(color='black', family=font_family),
    legend_title="",
    xaxis_tickangle=-45,
    margin=dict(l=20, r=20, t=30, b=20)
)
##########################################################
# Use the reusable function to format the y-axis in dollar style
format_y_axis_dollar(bars)

# Show the figure
bars.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="afb6ec36-af73-4b42-89e3-3fe35f8ee426" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("afb6ec36-af73-4b42-89e3-3fe35f8ee426")) {                    Plotly.newPlot(                        "afb6ec36-af73-4b42-89e3-3fe35f8ee426",                        [{"alignmentgroup":"True","hovertemplate":"Category=Below Median\u003cbr\u003eTown=%{x}\u003cbr\u003eMedian_Sold=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Below Median","marker":{"color":"red","pattern":{"shape":""}},"name":"Below Median","offsetgroup":"Below Median","orientation":"v","showlegend":true,"textposition":"auto","x":["Roosevelt","Hempstead","Freeport","East Rockaway","Uniondale","Baldwin","Levitown","Bethpage","Hicksville"],"xaxis":"x","y":[554000,560000,565000,579000,582000,608000,612000,650000,659000],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=Median\u003cbr\u003eTown=%{x}\u003cbr\u003eMedian_Sold=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Median","marker":{"color":"blue","pattern":{"shape":""}},"name":"Median","offsetgroup":"Median","orientation":"v","showlegend":true,"textposition":"auto","x":["Farmingdale","Mineola","East Meadow","Westbury"],"xaxis":"x","y":[680000,700000,710000,715000],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=Above Median\u003cbr\u003eTown=%{x}\u003cbr\u003eMedian_Sold=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Above Median","marker":{"color":"green","pattern":{"shape":""}},"name":"Above Median","offsetgroup":"Above Median","orientation":"v","showlegend":true,"textposition":"auto","x":["Floral Park","New Hyde Park","Locust Valley","Port Washington","Roslyns","Great Neck","Oyster Bay Cove","Sands Point"],"xaxis":"x","y":[765000,800000,950000,1100000,1300000,1400000,2000000,2446000],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222 ...

# %% [markdown]
# # And these are the 9 towns that we will look at

# %%
import plotly.express as px
import pandas as pd

def format_y_axis_dollar(fig):
    """
    Format the y-axis of a Plotly figure to display values in dollar format.

    Parameters:
    - fig: The Plotly figure to which the formatting will be applied.
    """
    fig.update_layout(yaxis=dict(tickprefix="$", ticksuffix="", tickformat=","))
    return fig


# Provided data
town_data = {
    'Town': ['New Hyde Park', 'Bethpage', 'Levitown', 'Mineola', 'Great Neck', 'Roslyns',
             'Port Washington', 'East Meadow', 'Westbury', 'Hicksville', 'Freeport',
             'Hempstead', 'Uniondale', 'Roosevelt', 'Baldwin', 'Floral Park',
             'East Rockaway', 'Farmingdale', 'Locust Valley', 'Oyster Bay Cove', 'Sands Point'],
    'Median_Sold': [800000, 650000, 612000, 700000, 1400000, 1300000, 1100000, 710000,
                    715000, 659000, 565000, 560000, 582000, 554000, 608000, 765000,
                    579000, 680000, 950000, 2000000, 2446000],
    'Median_Category': ['Above Median', 'Below Median', 'Below Median', 'Median', 'Above Median',
                        'Above Median', 'Above Median', 'Median', 'Median', 'Below Median',
                        'Below Median', 'Below Median', 'Below Median', 'Below Median',
                        'Below Median', 'Above Median', 'Below Median', 'Median', 'Above Median',
                        'Above Median', 'Above Median']
}

median_category_data = pd.DataFrame(town_data)

# Filter for specific towns BEFORE sorting
filtered_data = median_category_data[median_category_data['Town'].isin(['Roosevelt', 'Hempstead', 'Freeport', 'Farmingdale', 'Mineola', 'Westbury', 'Roslyns', 'Port Washington', 'Locust Valley'])]

# Sort filtered data by 'Median_Sold' in ascending order
sorted_data = filtered_data.sort_values(by='Median_Sold', ascending=True)

# Define color map
color_map = {'Above Median': 'green', 'Median': 'blue', 'Below Median': 'red'}

# Create the bar chart
bars = px.bar(sorted_data,
              x='Town',
              y='Median_Sold',
              color='Median_Category',
              color_discrete_map=color_map,
              labels={'Median_Category': 'Category'})

# Add a horizontal line at y=710000
bars.add_hline(y=710000, line_dash="solid", line_color="black", annotation_text="Benchmark", annotation_position="bottom right")

# Calculate the start and end points based on the categorical x-axis
start_x = 0  # The first category
end_x = len(sorted_data['Town']) - 1  # The last category, adjusted for 0-indexing

# Add a shaded area for the range ±50000 from 710000
bars.add_shape(type="rect",
               x0=start_x, y0=660000, x1=end_x, y1=760000,
               line=dict(width=0),
               fillcolor="gray", opacity=0.5)

### TEST
# Add a horizontal line at y=431000
bars.add_hline(y=431000, line_dash="solid", line_color="red", line_width=4)
# Annotation for line at y=431000
bars.add_annotation(x=end_x/2, y=431000,
                    text="US Medain sold Price 2023: $431,000",
                    showarrow=True,
                    arrowhead=2,
                    arrowsize=1,
                    arrowwidth=2,
                    arrowcolor="red",
                    ax=20,  # Horizontal offset
                    ay=-150)  # Vertical offset

###

# Add annotations correctly placed within the categorical x-axis
bars.add_annotation(x=sorted_data.iloc[int(len(sorted_data['Town'])*0.25)]['Town'], y=710000,
                    text="Nassau Median Sale Price $710k",
                    showarrow=True,
                    arrowhead=1,
                    arrowsize=2,
                    arrowwidth=2,
                    arrowcolor="black",
                    ax=-50,
                    ay=-30)

# Economist-style theming
economist_red = '#e3120b'
background_color = 'rgb(195, 215, 227)'
font_family = "Arial, sans-serif"

# Customize the plot with Economist styling
bars.update_layout(
    title={'text': "Median Sold Price Nassau County, NY 2023", 'y':0.9, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
    title_font=dict(size=18, color=economist_red, family=font_family),
    plot_bgcolor=background_color,
    paper_bgcolor=background_color,
    font=dict(color='black', family=font_family),
    legend_title="",
    xaxis_tickangle=-45,
    margin=dict(l=20, r=20, t=30, b=20)
)

# Use the reusable function to format the y-axis in dollar style
format_y_axis_dollar(bars)


# Show the figure
bars.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="63484edc-0064-4c9b-a9d9-4b01bde7ba6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63484edc-0064-4c9b-a9d9-4b01bde7ba6b")) {                    Plotly.newPlot(                        "63484edc-0064-4c9b-a9d9-4b01bde7ba6b",                        [{"alignmentgroup":"True","hovertemplate":"Category=Below Median\u003cbr\u003eTown=%{x}\u003cbr\u003eMedian_Sold=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Below Median","marker":{"color":"red","pattern":{"shape":""}},"name":"Below Median","offsetgroup":"Below Median","orientation":"v","showlegend":true,"textposition":"auto","x":["Roosevelt","Hempstead","Freeport"],"xaxis":"x","y":[554000,560000,565000],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=Median\u003cbr\u003eTown=%{x}\u003cbr\u003eMedian_Sold=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Median","marker":{"color":"blue","pattern":{"shape":""}},"name":"Median","offsetgroup":"Median","orientation":"v","showlegend":true,"textposition":"auto","x":["Farmingdale","Mineola","Westbury"],"xaxis":"x","y":[680000,700000,715000],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=Above Median\u003cbr\u003eTown=%{x}\u003cbr\u003eMedian_Sold=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Above Median","marker":{"color":"green","pattern":{"shape":""}},"name":"Above Median","offsetgroup":"Above Median","orientation":"v","showlegend":true,"textposition":"auto","x":["Locust Valley","Port Washington","Roslyns"],"xaxis":"x","y":[950000,1100000,1300000],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type": ...

# %% [markdown]
# # The differences between towns continues. Within towns there is variety. Not every town appreciates each house style equaly. The left axis is  how many homes were sold between 2006 and 2024. The number inside  the box tells us the median selling price of that Style of house during that lengthy period.

# %%
import plotly.graph_objects as go
import pandas as pd
import plotly.express as px  # Ensure Plotly Express is imported

# Assuming 'data' is your DataFrame

# Calculate median sold prices for each style within each town
style_median_prices = data.groupby(['Town', 'Style'])['Sold_Price'].median().reset_index()

# Calculate overall median sold price for each town
town_median_prices = data.groupby('Town')['Sold_Price'].median().reset_index()

# Sort towns based on their overall median sold price
sorted_towns = town_median_prices.sort_values('Sold_Price', ascending=True)['Town']

# Get unique styles
unique_styles = style_median_prices['Style'].unique()

# Assign a unique color to each style
colors = px.colors.qualitative.Plotly  # Or any other color sequence
style_color_map = {style: colors[i % len(colors)] for i, style in enumerate(unique_styles)}

# Initialize an empty figure
fig = go.Figure()

# Track which styles have been added to the legend
styles_added_to_legend = set()

# For each town, add a bar for each style in ascending order of median sold price
for town in sorted_towns:
    # Sort styles within the town by median sold price in ascending order
    town_data = style_median_prices[style_median_prices['Town'] == town].sort_values('Sold_Price', ascending=True)

    for _, row in town_data.iterrows():
        style_count = data[(data['Town'] == town) & (data['Style'] == row['Style'])].shape[0]
        show_in_legend = row['Style'] not in styles_added_to_legend
        styles_added_to_legend.add(row['Style'])

        fig.add_trace(go.Bar(
            name=row['Style'],
            x=[town],
            y=[style_count],
            marker_color=style_color_map[row['Style']],  # Use the assigned color
            hoverinfo='text',
            text=f"${row['Sold_Price']}",
            textposition='inside',
            showlegend=show_in_legend  # Only show in legend if not already added
        ))

# Customize the layout
fig.update_layout(
    barmode='relative',  # Use 'relative' to stack bars
    # Add any additional customization here
)

# Economist-style customizations
economist_red = '#e3120b'
background_color = 'rgb(195, 215, 227)'
font_family = "Arial, sans-serif"

fig.update_layout(
    title={'text': "Different Towns, different Styles", 'y':0.9, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
    title_font=dict(size=18, color=economist_red, family=font_family),
    plot_bgcolor=background_color,
    paper_bgcolor=background_color,
    font=dict(color='black', family=font_family),
    legend_title="House Styles"
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d70b578c-a6ec-4a19-b656-02107bd5b1da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d70b578c-a6ec-4a19-b656-02107bd5b1da")) {                    Plotly.newPlot(                        "d70b578c-a6ec-4a19-b656-02107bd5b1da",                        [{"hoverinfo":"text","marker":{"color":"#AB63FA"},"name":"Ranch","showlegend":true,"text":"$278500.0","textposition":"inside","x":["Roosevelt"],"y":[259],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#636EFA"},"name":"Cape","showlegend":true,"text":"$283750.0","textposition":"inside","x":["Roosevelt"],"y":[458],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#EF553B"},"name":"Colonial","showlegend":true,"text":"$323500.0","textposition":"inside","x":["Roosevelt"],"y":[493],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#00CC96"},"name":"Other","showlegend":true,"text":"$325000.0","textposition":"inside","x":["Roosevelt"],"y":[425],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#FFA15A"},"name":"Split Level","showlegend":true,"text":"$343500.0","textposition":"inside","x":["Roosevelt"],"y":[180],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#AB63FA"},"name":"Ranch","showlegend":false,"text":"$319000.0","textposition":"inside","x":["Hempstead"],"y":[366],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#636EFA"},"name":"Cape","showlegend":false,"text":"$335000.0","textposition":"inside","x":["Hempstead"],"y":[876],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#EF553B"},"name":"Colonial","showlegend":false,"text":"$350000.0","textposition":"inside","x":["Hempstead"],"y":[1433],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#FFA15A"},"name":"Split Level","showlegend":false,"text":"$381500.0","textposition":"inside","x":["Hempstead"],"y":[48],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#00CC96"},"name":"Other","showlegend":false,"text":"$395000.0","textposition":"inside","x":["Hempstead"],"y":[785],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#AB63FA"},"name":"Ranch","showlegend":false,"text":"$317500.0","textposition":"inside","x":["Freeport"],"y":[436],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#636EFA"},"name":"Cape","showlegend":false,"text":"$320500.0","textposition":"inside","x":["Freeport"],"y":[488],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#EF553B"},"name":"Colonial","showlegend":false,"text":"$379000.0","textposition":"inside","x":["Freeport"],"y":[1272],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#FFA15A"},"name":"Split Level","showlegend":false,"text":"$380000.0","textposition":"inside","x":["Freeport"],"y":[438],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#00CC96"},"name":"Other","showlegend":false,"text":"$400000.0","textposition":"inside","x":["Freeport"],"y":[984],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#636EFA"},"name":"Cape","showlegend":false,"text":"$380000.0","textposition":"inside","x":["Farmingdale"],"y":[792],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#AB63FA"},"name":"Ranch","showlegend":false,"text":"$385000.0","textposition":"inside","x":["Farmingdale"],"y":[710],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#FFA15A"},"name":"Split Level","showlegend":false,"text":"$437700.0","textposition":"inside","x":["Farmingdale"],"y":[632],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#00CC96"},"name":"Other","showlegend":false,"text":"$440000.0","textposition":"inside","x":["Farmingdale"],"y":[1139],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#EF553B"},"name":"Colonial","showlegend":false,"text":"$487000.0","textposition":"inside","x":["Farmingdale"],"y":[704],"type":"bar"},{"hoverinfo":"text","marker":{"color":"#63 ...

# %%
# import pandas as pd

# # Assuming 'data' is your DataFrame

# # List of specific towns to include in the analysis
# #specific_towns = ['Roosevelt', 'Hempstead', 'Freeport', 'Farmingdale', 'Mineola', 'Westbury', 'Roslyns', 'Port Washington', 'Locust Valley']
# specific_towns = ['Roosevelt', 'Hempstead', 'Freeport', 'Farmingdale', 'Mineola', 'Westbury', 'Locust Valley', 'Port Washington', 'Roslyns']

# # Filter the dataframe to include only the specified towns
# filtered_data = data[data['Town'].isin(specific_towns)]

# # Group by 'Town' and 'Style', then calculate the count and median sold price
# grouped = filtered_data.groupby(['Town', 'Style']).agg(
#     Units_Sold=('Sold_Price', 'size'),  # Count of units sold
#     Median_Sold_Price=('Sold_Price', 'median')  # Median of sold price
# ).reset_index()

# # Sort the result for readability or further analysis if necessary
# # For example, sorting by 'Town' and then 'Median_Sold_Price' in descending order
# sorted_grouped = grouped.sort_values(by=['Town', 'Median_Sold_Price'], ascending=[True, False])

# # Reset the index if you want to clean up the index after sorting
# sorted_grouped = sorted_grouped.reset_index(drop=True)

# # Display the first few rows to verify
# print(sorted_grouped.head())

# %%
# import plotly.graph_objects as go
# import pandas as pd

# # Assuming 'data' is your DataFrame and it contains 'Town', 'Style', and 'Sold_Price' columns

# ####### Style color mapping block ############
# style_color_mapping = {
#     'Cape': 'blue',
#     'Colonial': 'red',
#     'Other': 'green',
#     'Ranch': 'purple',
#     'Split Level': 'orange'
# }
# ##############################################

# # Your data filtering and grouping logic here...

# # Initialize an empty figure
# fig = go.Figure()

# # Iterate over each town to add bars for each style, ensuring they're stacked in descending order of median price
# for town in specific_towns:
#     town_data = grouped_data_sorted[grouped_data_sorted['Town'] == town]

#     # Reverse the iteration order here to stack highest values at the top
#     for _, row in town_data.iloc[::-1].iterrows():  # This reverses the order of rows for each town
#         fig.add_trace(go.Bar(
#             name=row['Style'],
#             x=[row['Town']],
#             y=[row['Units_Sold']],
#             marker_color=style_color_mapping.get(row['Style'], 'grey'),
#             hoverinfo='text',
#             text=f"${row['Median_Sold_Price']:,.0f}",
#             textposition='inside',
#             legendgroup=row['Style'],  # This groups the legend entries by style
#             showlegend=(town == specific_towns[0])  # Only show legend for the first occurrence of each style
#         ))

# # Customize the layout
# fig.update_layout(
#     barmode='stack',
#     title={'text': "Number of Units Sold by Style Per Town, Sorted by Median Price", 'y':0.9, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
#     # Additional layout customizations here
# )

# ########### ECONOMIST STYLING ###############
# # Economist-style theming
# economist_red = '#e3120b'
# background_color = 'rgb(195, 215, 227)'
# font_family = "Arial, sans-serif"

# # Customize the plot with Economist styling
# fig.update_layout(
#     title={'text': "Different Towns, Different Styles", 'y':0.95, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
#     title_font=dict(size=18, color=economist_red, family=font_family),
#     plot_bgcolor=background_color,
#     paper_bgcolor=background_color,
#     font=dict(color='black', family=font_family),
#     legend_title="",
#     xaxis_tickangle=-45,
#     margin=dict(l=20, r=20, t=30, b=20)
# )

# fig.update_layout(
#     width=800,  # Adjust the width as needed
#     height=600,  # Adjust the height as needed
# )

# ###################################################
# # Show the plot
# fig.show()

# %% [markdown]
# # So what then was the bes tinvestment in RE sinc e 2006 in Nassau county, New York

# %% [markdown]
# # Income change in each town btween 2006 and 2024

# %%
import plotly.express as px

# Make sure your DataFrame is named med_incomes and it's properly loaded

# Correct any potential mismatch in town names in the DataFrame vs. color_dict keys
# Ensure the 'Town' column of your DataFrame exactly matches these keys
color_dict = {
    'Roslyns': '#006400',  # DarkGreen
    'Port_Washington': '#008000',  # Green
    'Locust_Valley': '#90EE90',  # LightGreen
    'Mineola': '#00008B',  # DarkBlue
    'Westbury': '#0000FF',  # Blue
    'Farmingdale': '#ADD8E6',  # LightBlue
    'Freeport': '#8B0000',  # DarkRed
    'Hempstead': '#FF0000',  # Red
    'Roosevelt': '#F08080'  # LightCoral
}

# Specify the order of towns
town_order = ['Roosevelt', 'Hempstead', 'Freeport', 'Farmingdale', 'Mineola',
              'Westbury', 'Roslyns', 'Port_Washington', 'Locust_Valley']

# Use the 'category_orders' parameter to specify the order of towns
fig = px.bar(mean_incomnes,
             x="Year",
             y="Mean_Income",
             color="Town",
             barmode='group',
             color_discrete_map=color_dict,
             category_orders={"Town": town_order})

fig.update_layout(
    title="Average Household Income by Town and Year",
    xaxis_title="",
    yaxis_title="Average Household Income",
    legend_title="Town"
)

# This ensures the legend order matches the town order specified
fig.update_traces(marker=dict(line=dict(width=0)))
fig.update_layout(legend=dict(traceorder="normal"))

###############################################
##### Economist-style customizations
economist_red = '#e3120b'
background_color = 'rgb(195, 215, 227)'
font_family = "Arial, sans-serif"

fig.update_layout(
    title={'text': "Average Household Income", 'y':0.9, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
    title_font=dict(size=18, color=economist_red, family=font_family),
    plot_bgcolor=background_color,
    paper_bgcolor=background_color,
    font=dict(color='black', family=font_family),
    legend_title="House Styles"
)
###############################################

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8c2de07c-5ed3-4a5b-8bac-be7aae5e022e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c2de07c-5ed3-4a5b-8bac-be7aae5e022e")) {                    Plotly.newPlot(                        "8c2de07c-5ed3-4a5b-8bac-be7aae5e022e",                        [{"alignmentgroup":"True","hovertemplate":"Town=Roosevelt\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Roosevelt","marker":{"color":"#F08080","pattern":{"shape":""},"line":{"width":0}},"name":"Roosevelt","offsetgroup":"Roosevelt","orientation":"v","showlegend":true,"textposition":"auto","x":[2000,2010,2020],"xaxis":"x","y":[61758,78509,109155],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Town=Hempstead\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hempstead","marker":{"color":"#FF0000","pattern":{"shape":""},"line":{"width":0}},"name":"Hempstead","offsetgroup":"Hempstead","orientation":"v","showlegend":true,"textposition":"auto","x":[2000,2010,2020],"xaxis":"x","y":[59213,64221,91477],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Town=Freeport\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Freeport","marker":{"color":"#8B0000","pattern":{"shape":""},"line":{"width":0}},"name":"Freeport","offsetgroup":"Freeport","orientation":"v","showlegend":true,"textposition":"auto","x":[2000,2010,2020],"xaxis":"x","y":[66755,86662,108102],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Town=Farmingdale\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Farmingdale","marker":{"color":"#ADD8E6","pattern":{"shape":""},"line":{"width":0}},"name":"Farmingdale","offsetgroup":"Farmingdale","orientation":"v","showlegend":true,"textposition":"auto","x":[2000,2010,2020],"xaxis":"x","y":[72506,99253,138851],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Town=Mineola\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mineola","marker":{"color":"#00008B","pattern":{"shape":""},"line":{"width":0}},"name":"Mineola","offsetgroup":"Mineola","orientation":"v","showlegend":true,"textposition":"auto","x":[2000,2010,2020],"xaxis":"x","y":[74195,90171,124774],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Town=Westbury\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Westbury","marker":{"color":"#0000FF","pattern":{"shape":""},"line":{"width":0}},"name":"Westbury","offsetgroup":"Westbury","orientation":"v","showlegend":true,"textposition":"auto","x":[2000,2010,2020],"xaxis":"x","y":[83826,98377,140533],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Town=Roslyns\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Roslyns","marker":{"color":"#006400","pattern":{"shape":""},"line":{"width":0}},"name":"Roslyns","offsetgroup":"Roslyns","orientation":"v","showlegend":true,"textposition":"auto","x":[2000,2010,2020],"xaxis":"x","y":[131770,192091,214591],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Town=Port_Washington\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Port_Washington","marker":{"color":"#008000","pattern":{"shape":""},"line":{"width":0}},"name":"Port_Washington","offsetgroup":"Port_Washington","orientation":"v","showlegend":true,"textposition":"auto","x":[2000,2010,2020],"xaxis":"x ...

# %% [markdown]
# # compare lot size and selling price
