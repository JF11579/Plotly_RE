# %% [markdown]
# <a href="https://colab.research.google.com/github/JF11579/Plotly_RE/blob/main/SameHouse/Income_Per_Town.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data store in Political and popilation

# %%
# api_key = "6eff16100e6184b9bf0604e510aeba4d429a7dec"

# %%
# ['Roosevelt', 'Hempstead', 'Freeport', 'Farmingdale', 'Mineola','Westbury','Roslyn Harbor','Roslyn','Roslyn heights',  'Port Washington', 'Locust Valley'])]

# %%
# Roosevelt: 366620
# Hempstead: 362900
# Freeport: 362560
# Farmingdale: 362440
# Mineola: 364440
# Westbury: 368520
# Roslyn Harbor: 366700
# Roslyn: 366720
# Roslyn Heights: 366740
# Port Washington: 365980
# Locust Valley: 364200

# %% [markdown]
# # Library

# %%
import pandas as pd
from google.colab import drive  # <<<<<<<<<------
import plotly.express as px
import numpy as np
import plotly.graph_objects as go

# %% [markdown]
# # Options

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Data

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Change to the directory containing your CSV
# %cd /content/drive/MyDrive/DATA/Population_and_Political_Data
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/DATA/Population_and_Political_Data

# %%
#med_incomnes =  pd.read_csv('Median_Incomes_9_towns.csv')
#Avg_and_Median_Incomes_9_towns - Sheet1 (1).csv
mean_incomnes =  pd.read_csv('Avg_and_Median_Incomes_9_towns - Sheet1 (1).csv')

# %%
mean_incomnes.head(3)
# Out:
#         Town  Year  Median_Income  Mean_Income
# 0  Hempstead  2000          46675        59213
# 1  Hempstead  2010          53333        64221
# 2  Hempstead  2020          68946        91477

# %%
# prompt: drop Median_Income

mean_incomnes.drop(columns=['Median_Income'], axis=1, inplace=True)

# %%
mean_incomnes.head(3)
# Out:
#         Town  Year  Mean_Income
# 0  Hempstead  2000        59213
# 1  Hempstead  2010        64221
# 2  Hempstead  2020        91477

# %%
# # Mount Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# # Change to the directory containing your CSV
# %cd /content/drive/MyDrive/DATA/Real_Estate_Data

# %%
# # prompt: create plotly  muklti line chart,  x = Year, y = Household_Income, color = town

# fig = px.line(med_incomnes, x="Year", y="Household_Income", color='Town')
# fig.show()

# %%
# prompt: get unique town

unique_towns = mean_incomnes['Town'].unique()
print(unique_towns)
# Out:
# ['Hempstead' 'Freeport' 'Farmingdale' 'Mineola' 'Westbury' 'Roslyn_Harbor'
#  'Roslyn' 'Roslyn_Heights' 'Port_Washington' 'Locust_Valley' 'Roosevelt']

# %%
mean_incomnes.head(3)
# Out:
#    Year         Town  Mean_Income
# 0  2000  Farmingdale        72506
# 1  2000     Freeport        66755
# 2  2000    Hempstead        59213

# %%
import plotly.express as px

# Assuming mean_incomes is your DataFrame
# Corrected the typo from 'mean_incomnes' to 'mean_incomes'
fig = px.line(mean_incomnes, x="Year", y="Mean_Income", color='Town', color_discrete_map=color_dict)  # Use color_discrete_map

# Economist-style customizations
economist_red = '#e3120b'
background_color = 'rgb(195, 215, 227)'
font_family = "Arial, sans-serif"

fig.update_layout(
    title={'text': "Average Household Income", 'y':0.9, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
    title_font=dict(size=18, color=economist_red, family=font_family),
    plot_bgcolor=background_color,
    paper_bgcolor=background_color,
    font=dict(color='black', family=font_family),
    legend_title="Town"  # Corrected to match the column you're visualizing
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5a774437-6b7a-4a5c-9493-61b9a2414a52" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a774437-6b7a-4a5c-9493-61b9a2414a52")) {                    Plotly.newPlot(                        "5a774437-6b7a-4a5c-9493-61b9a2414a52",                        [{"hovertemplate":"Town=Farmingdale\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Farmingdale","line":{"color":"#ADD8E6","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Farmingdale","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[72506,99253,138851],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Freeport\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Freeport","line":{"color":"#8B0000","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Freeport","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[66755,86662,108102],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Hempstead\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hempstead","line":{"color":"#FF0000","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Hempstead","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[59213,64221,91477],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Locust_Valley\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Locust_Valley","line":{"color":"#90EE90","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Locust_Valley","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[96067,110743,226535],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Mineola\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mineola","line":{"color":"#00008B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Mineola","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[74195,90171,124774],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Port_Washington\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Port_Washington","line":{"color":"#008000","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Port_Washington","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[122357,155366,217492],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Roosevelt\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Roosevelt","line":{"color":"#F08080","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Roosevelt","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[61758,78509,109155],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Roslyns\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Roslyns","line":{"color":"#006400","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Roslyns","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[131770,192091,214591],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Westbury\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Westbury","line":{"color":"#0000FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Westbury","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[83826,98377,140533],"yaxis ...

# %%
import pandas as pd

# Read the CSV file into a DataFrame
#med_incomes = pd.read_csv('Median_Incomes_9_towns.csv')
mean_incomnes =  pd.read_csv('Avg_and_Median_Incomes_9_towns - Sheet1 (1).csv')

# Define the towns to combine
roslyn_towns = ['Roslyn_Harbor', 'Roslyn', 'Roslyn_Heights']

# Create a copy of the DataFrame to avoid modifying the original
combined_data = mean_incomnes.copy()

# Combine rows with Roslyn town names
combined_data.loc[combined_data['Town'].isin(roslyn_towns), 'Town'] = 'Roslyns'

# Group data by Year and Town, calculate average household income
average_income_per_town_year = combined_data.groupby(['Year', 'Town'])['Mean_Income'].mean().reset_index()

# Update the original DataFrame with the combined data
mean_incomnes = average_income_per_town_year

# Print the updated DataFrame
print(mean_incomnes)
# Out:
#     Year             Town    Mean_Income
# 0   2000      Farmingdale   72506.000000
# 1   2000         Freeport   66755.000000
# 2   2000        Hempstead   59213.000000
# 3   2000    Locust_Valley   96067.000000
# 4   2000          Mineola   74195.000000
# 5   2000  Port_Washington  122357.000000
# 6   2000        Roosevelt   61758.000000
# 7   2000          Roslyns  131770.000000
# 8   2000         Westbury   83826.000000
# 9   2010      Farmingdale   99253.000000
# 10  2010         Freeport   86662.000000
# 11  2010        Hempstead   64221.000000
# 12  2010    Locust_Valley  110743.000000
# 13  2010          Mineola   90171.000000
# 14  2010  Port_Washington  155366.000000
# 15  2010        Roosevelt   78509.000000
# 16  2010          Roslyns  192091.666667
# 17  2010         Westbury   98377.000000
# 18  2020      Farmingdale  138851.000000
# 19  2020         Freeport  108102.000000
# 20  2020        Hempstead   91477.000000
# 21  2020    Locust_Valley  226535.000000
# 22  2020          Mineola  124774.000000
# 23  2020  Port_Washington  217492.000000
# 24  2020        Roosevelt  109155.000000
# 25  2020          Roslyns  214591.000000
# 26  2020         Westbury  140533.000000

# %%
# prompt: convert  Household_Income to integer

mean_incomnes['Mean_Income'] = mean_incomnes['Mean_Income'].astype(int)

# %%
mean_incomnes.head(3)
# Out:
#    Year         Town  Mean_Income
# 0  2000  Farmingdale        72506
# 1  2000     Freeport        66755
# 2  2000    Hempstead        59213

# %%
fig = px.line(mean_incomnes, x="Year", y="Mean_Income", color='Town')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d286826e-1c8c-43bf-83b4-7d839bd290b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d286826e-1c8c-43bf-83b4-7d839bd290b2")) {                    Plotly.newPlot(                        "d286826e-1c8c-43bf-83b4-7d839bd290b2",                        [{"hovertemplate":"Town=Farmingdale\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Farmingdale","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Farmingdale","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[72506,99253,138851],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Freeport\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Freeport","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Freeport","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[66755,86662,108102],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Hempstead\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hempstead","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Hempstead","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[59213,64221,91477],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Locust_Valley\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Locust_Valley","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Locust_Valley","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[96067,110743,226535],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Mineola\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mineola","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Mineola","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[74195,90171,124774],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Port_Washington\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Port_Washington","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Port_Washington","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[122357,155366,217492],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Roosevelt\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Roosevelt","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Roosevelt","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[61758,78509,109155],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Roslyns\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Roslyns","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Roslyns","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[131770,192091,214591],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Westbury\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Westbury","line":{"color":"#FF97FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Westbury","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[83826,98377,140533],"yaxis ...

# %%
# import matplotlib.pyplot as plt

# # Assuming med_incomes is your updated DataFrame with combined Roslyn towns as 'Roslyns'
# # and it has columns 'Year', 'Town', and 'Household_Income'

# # Pivot the data for easier plotting: rows are years, columns are towns, values are income
# pivot_table = med_incomes.pivot(index='Year', columns='Town', values='Household_Income')

# # Plot
# pivot_table.plot(kind='bar', figsize=(10, 7))
# plt.title('Average Household Income by Town and Year')
# plt.xlabel('Year')
# plt.ylabel('Average Household Income')
# plt.xticks(rotation=45)
# plt.legend(title='Town')
# plt.tight_layout()  # Adjust layout to not cut off labels
# plt.show()

# %%
#pivot_table

# %%
import plotly.express as px

# Assuming mean_incomes is your DataFrame
# Corrected the typo from 'mean_incomnes' to 'mean_incomes'
fig = px.line(mean_incomes, x="Year", y="Mean_Income", color='Town', color_discrete_map=color_dict)  # Use color_discrete_map

# Economist-style customizations
economist_red = '#e3120b'
background_color = 'rgb(195, 215, 227)'
font_family = "Arial, sans-serif"

fig.update_layout(
    title={'text': "Average Household Income", 'y':0.9, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
    title_font=dict(size=18, color=economist_red, family=font_family),
    plot_bgcolor=background_color,
    paper_bgcolor=background_color,
    font=dict(color='black', family=font_family),
    legend_title="Town"  # Corrected to match the column you're visualizing
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-5ef2de93bdef> in <cell line: 5>()
#       3 # Assuming mean_incomes is your DataFrame
#       4 # Corrected the typo from 'mean_incomnes' to 'mean_incomes'
# ----> 5 fig = px.line(mean_incomes, x="Year", y="Mean_Income", color='Town', color_discrete_map=color_dict)  # Use color_discrete_map
#       6
#       7 # Economist-style customizations
#
# NameError: name 'mean_incomes' is not defined

# %%
import plotly.express as px

color_dict = {
    'Roslyns': '#006400',  # DarkGreen
    'Port_Washington': '#008000',  # Green
    'Locust_Valley': '#90EE90',  # LightGreen
    'Mineola': '#00008B',  # DarkBlue
    'Westbury': '#0000FF',  # Blue
    'Farmingdale': '#ADD8E6',  # LightBlue
    'Freeport': '#8B0000',  # DarkRed
    'Hempstead': '#FF0000',  # Red
    'Roosevelt': '#F08080'  # LightCoral
}


# Assuming med_incomes is your DataFrame with the combined Roslyn towns as 'Roslyns'
fig = px.line(mean_incomnes, x="Year", y="Mean_Income", color='Town')

###############################################
##### Economist-style customizations
economist_red = '#e3120b'
background_color = 'rgb(195, 215, 227)'
font_family = "Arial, sans-serif"

fig.update_layout(
    title={'text': "Average Household Income", 'y':0.9, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
    title_font=dict(size=18, color=economist_red, family=font_family),
    plot_bgcolor=background_color,
    paper_bgcolor=background_color,
    font=dict(color='black', family=font_family),
    legend_title="House Styles"
)
###############################################
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="498ee3f2-fb0e-4a4c-a2de-48754bfa39da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("498ee3f2-fb0e-4a4c-a2de-48754bfa39da")) {                    Plotly.newPlot(                        "498ee3f2-fb0e-4a4c-a2de-48754bfa39da",                        [{"hovertemplate":"Town=Farmingdale\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Farmingdale","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Farmingdale","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[72506,99253,138851],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Freeport\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Freeport","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Freeport","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[66755,86662,108102],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Hempstead\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hempstead","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Hempstead","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[59213,64221,91477],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Locust_Valley\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Locust_Valley","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Locust_Valley","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[96067,110743,226535],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Mineola\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mineola","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Mineola","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[74195,90171,124774],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Port_Washington\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Port_Washington","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Port_Washington","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[122357,155366,217492],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Roosevelt\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Roosevelt","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Roosevelt","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[61758,78509,109155],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Roslyns\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Roslyns","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Roslyns","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[131770,192091,214591],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Westbury\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Westbury","line":{"color":"#FF97FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Westbury","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[83826,98377,140533],"yaxis ...

# %%
import plotly.express as px

# Assuming med_incomes is your DataFrame with the combined Roslyn towns as 'Roslyns'
fig = px.line(mean_incomnes, x="Year", y="Mean_Income", color='Town')

###############################################
##### Economist-style customizations
economist_red = '#e3120b'
background_color = 'rgb(195, 215, 227)'
font_family = "Arial, sans-serif"

fig.update_layout(
    title={'text': "Average Household Income", 'y':0.9, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
    title_font=dict(size=18, color=economist_red, family=font_family),
    plot_bgcolor=background_color,
    paper_bgcolor=background_color,
    font=dict(color='black', family=font_family),
    legend_title="House Styles"
)
###############################################
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cbb15367-6c44-4d3a-bc64-b37cc71df38a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cbb15367-6c44-4d3a-bc64-b37cc71df38a")) {                    Plotly.newPlot(                        "cbb15367-6c44-4d3a-bc64-b37cc71df38a",                        [{"hovertemplate":"Town=Farmingdale\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Farmingdale","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Farmingdale","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[72506,99253,138851],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Freeport\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Freeport","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Freeport","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[66755,86662,108102],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Hempstead\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hempstead","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Hempstead","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[59213,64221,91477],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Locust_Valley\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Locust_Valley","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Locust_Valley","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[96067,110743,226535],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Mineola\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mineola","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Mineola","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[74195,90171,124774],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Port_Washington\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Port_Washington","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Port_Washington","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[122357,155366,217492],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Roosevelt\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Roosevelt","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Roosevelt","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[61758,78509,109155],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Roslyns\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Roslyns","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Roslyns","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[131770,192091,214591],"yaxis":"y","type":"scatter"},{"hovertemplate":"Town=Westbury\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Westbury","line":{"color":"#FF97FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Westbury","orientation":"v","showlegend":true,"x":[2000,2010,2020],"xaxis":"x","y":[83826,98377,140533],"yaxis ...

# %%
# prompt: unique Town

unique_towns = mean_incomnes['Town'].unique()
print(unique_towns)
# Out:
# ['Farmingdale' 'Freeport' 'Hempstead' 'Locust_Valley' 'Mineola'
#  'Port_Washington' 'Roosevelt' 'Roslyns' 'Westbury']

# %%
import plotly.express as px

# Make sure your DataFrame is named med_incomes and it's properly loaded

# Correct any potential mismatch in town names in the DataFrame vs. color_dict keys
# Ensure the 'Town' column of your DataFrame exactly matches these keys
color_dict = {
    'Roslyns': '#006400',  # DarkGreen
    'Port_Washington': '#008000',  # Green
    'Locust_Valley': '#90EE90',  # LightGreen
    'Mineola': '#00008B',  # DarkBlue
    'Westbury': '#0000FF',  # Blue
    'Farmingdale': '#ADD8E6',  # LightBlue
    'Freeport': '#8B0000',  # DarkRed
    'Hempstead': '#FF0000',  # Red
    'Roosevelt': '#F08080'  # LightCoral
}

# Specify the order of towns
town_order = ['Roosevelt', 'Hempstead', 'Freeport', 'Farmingdale', 'Mineola',
              'Westbury', 'Roslyns', 'Port_Washington', 'Locust_Valley']

# Use the 'category_orders' parameter to specify the order of towns
fig = px.bar(mean_incomnes,
             x="Year",
             y="Mean_Income",
             color="Town",
             barmode='group',
             color_discrete_map=color_dict,
             category_orders={"Town": town_order})

fig.update_layout(
    title="Average Household Income by Town and Year",
    xaxis_title="",
    yaxis_title="Average Household Income",
    legend_title="Town"
)

# This ensures the legend order matches the town order specified
fig.update_traces(marker=dict(line=dict(width=0)))
fig.update_layout(legend=dict(traceorder="normal"))

###############################################
##### Economist-style customizations
economist_red = '#e3120b'
background_color = 'rgb(195, 215, 227)'
font_family = "Arial, sans-serif"

fig.update_layout(
    title={'text': "Average Household Income", 'y':0.9, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
    title_font=dict(size=18, color=economist_red, family=font_family),
    plot_bgcolor=background_color,
    paper_bgcolor=background_color,
    font=dict(color='black', family=font_family),
    legend_title="House Styles"
)
###############################################

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="da1884b2-b34c-40b7-a5c1-e1c12c38e3a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da1884b2-b34c-40b7-a5c1-e1c12c38e3a9")) {                    Plotly.newPlot(                        "da1884b2-b34c-40b7-a5c1-e1c12c38e3a9",                        [{"alignmentgroup":"True","hovertemplate":"Town=Roosevelt\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Roosevelt","marker":{"color":"#F08080","pattern":{"shape":""},"line":{"width":0}},"name":"Roosevelt","offsetgroup":"Roosevelt","orientation":"v","showlegend":true,"textposition":"auto","x":[2000,2010,2020],"xaxis":"x","y":[61758,78509,109155],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Town=Hempstead\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hempstead","marker":{"color":"#FF0000","pattern":{"shape":""},"line":{"width":0}},"name":"Hempstead","offsetgroup":"Hempstead","orientation":"v","showlegend":true,"textposition":"auto","x":[2000,2010,2020],"xaxis":"x","y":[59213,64221,91477],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Town=Freeport\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Freeport","marker":{"color":"#8B0000","pattern":{"shape":""},"line":{"width":0}},"name":"Freeport","offsetgroup":"Freeport","orientation":"v","showlegend":true,"textposition":"auto","x":[2000,2010,2020],"xaxis":"x","y":[66755,86662,108102],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Town=Farmingdale\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Farmingdale","marker":{"color":"#ADD8E6","pattern":{"shape":""},"line":{"width":0}},"name":"Farmingdale","offsetgroup":"Farmingdale","orientation":"v","showlegend":true,"textposition":"auto","x":[2000,2010,2020],"xaxis":"x","y":[72506,99253,138851],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Town=Mineola\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mineola","marker":{"color":"#00008B","pattern":{"shape":""},"line":{"width":0}},"name":"Mineola","offsetgroup":"Mineola","orientation":"v","showlegend":true,"textposition":"auto","x":[2000,2010,2020],"xaxis":"x","y":[74195,90171,124774],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Town=Westbury\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Westbury","marker":{"color":"#0000FF","pattern":{"shape":""},"line":{"width":0}},"name":"Westbury","offsetgroup":"Westbury","orientation":"v","showlegend":true,"textposition":"auto","x":[2000,2010,2020],"xaxis":"x","y":[83826,98377,140533],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Town=Roslyns\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Roslyns","marker":{"color":"#006400","pattern":{"shape":""},"line":{"width":0}},"name":"Roslyns","offsetgroup":"Roslyns","orientation":"v","showlegend":true,"textposition":"auto","x":[2000,2010,2020],"xaxis":"x","y":[131770,192091,214591],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Town=Port_Washington\u003cbr\u003eYear=%{x}\u003cbr\u003eMean_Income=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Port_Washington","marker":{"color":"#008000","pattern":{"shape":""},"line":{"width":0}},"name":"Port_Washington","offsetgroup":"Port_Washington","orientation":"v","showlegend":true,"textposition":"auto","x":[2000,2010,2020],"xaxis":"x ...
