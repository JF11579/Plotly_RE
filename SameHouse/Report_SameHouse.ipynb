# %% [markdown]
# <a href="https://colab.research.google.com/github/JF11579/Plotly_RE/blob/main/SameHouse/Report_SameHouse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2024-01-10 at 1.26.35 PM.png](data:image/png;base64,...)

# %% [markdown]
# ### Starting in 2006 we look at one style of house and see how it has appreciated in dfferent towns compared to other house styles in that town. We will focus on 3 Bedroom Split Level houses.
#
# ### There are more than 60 Towns in Nassau county depending on how you define Town, City, Village , Hamlets. We will look not at every town but at representives of those Above, At , or Below the median price.  Here is how that looked unisng 2023 data.![TownsAboveBelowMedian.png](data:image/png;base64,...)

# %% [markdown]
# ## But we will focus on these 9 towns

# %% [markdown]
# ![newplot.png](data:image/png;base64,...)
