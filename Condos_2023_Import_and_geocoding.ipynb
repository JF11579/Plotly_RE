# %% [markdown]
# <a href="https://colab.research.google.com/github/JF11579/Plotly_RE/blob/main/Condos_2023_Import_and_geocoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Using the already assembled data frame Condos which includes corrected col andmes and geo data

# %% [markdown]
# Notes
# https://jf11579.github.io/Plotly_RE/condo_sold_prices
# code in colab.
#
# use that code to convert the graph to a html file and download it
#
# then find that just downloaded file , REVISE NAME, and move it to my Plotly_RE folder
#
# Git Hub will detect the new file
#
# Add a comment, COMMITm, push
#
# Now it is in my GH repo unde r5he PLOTLY RE

# %% [markdown]
# # Libraries

# %%
import pandas as pd
from google.colab import drive

# %%
# !pip install geopandas
# !pip install geopy

# %%
# from geopy.geocoders import Nominatim

# # Create a Nominatim geocoder object with a user agent
# geolocator = Nominatim(user_agent="myGeocoder")

# # geolocator = geocoders.Nominatim(user_agent="my_app")
#
from geopy.geocoders import Nominatim
import pandas as pd

# Create a GeoPy geocoder
geolocator = Nominatim(user_agent="my_app")

# %% [markdown]
# # Options

# %%
# Set pandas display options to show more rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Data

# %%
# # Mount Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# # Change to the directory containing your CSV
# %cd /content/drive/MyDrive/DATA/Real_Estate_Data

# # Check if the file exists in the subfolder
# import os
# file_name = 'RidgeSeldenBayShore.csv'
# if os.path.exists(file_name):
#     Ridge = pd.read_csv(file_name)
#     # Now you can work with the 'Ridge' DataFrame
# else:
#     print(f"File '{file_name}' not found in the subfolder.")

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Change to the directory containing your CSV
# %cd /content/drive/MyDrive/DATA/Real_Estate_Data
#
Ridge = pd.read_csv('RidgeSeldenBayShore.csv')
Islip = pd.read_csv('Islip_2023.csv')
Patch = pd.read_csv('Patch_2023.csv')
Coram = pd.read_csv('Coram_Mid_IsleManorville.csv')
#
Patch_2 = pd.read_csv('Patch_condos_sold_2023.csv')
Islip_2 = pd.read_csv('Islip_condo_sold_2023.csv')
MidIsle_Manor = pd.read_csv('Mid_Isle_Manorville_condos_sold_2023.csv')
Coram_2 = pd.read_csv('Coram_condos_2023_2.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/DATA/Real_Estate_Data

# %%
# # Mount Google Drive
# from google.colab import drive
# drive.mount('/content/drive')
# drive.mount('/content/drive', force_remount=True)
# /content/drive/MyDrive/DATA/Real_Estate_Data

# # Change the working directory to the 'data' folder
# %cd /content/drive/MyDrive/DATA/Real_Estate_Data


# Ridge = pd.read_csv('RidgeSeldenBayShore.csv')
# Islip = pd.read_csv('Islip_2023.csv')
# Patch = pd.read_csv('Patch_2023.csv')
# Coram = pd.read_csv('Coram_Mid_IsleManorville.csv')
# #
# Patch_2 = pd.read_csv('Patch_condos_sold_2023.csv')
# Islip_2 = pd.read_csv('Islip_condo_sold_2023.csv')
# MidIsle_Manor = pd.read_csv('Mid_Isle_Manorville_condos_sold_2023.csv')
# Coram_2 = pd.read_csv('Coram_condos_2023_2.csv')

# #condos = pd.read_csv('Condos_2023_Geocoded - condos_2023.csv')
# # Patch_condos_sold_2023.csv
# # Islip_condo_sold_2023.csv
# # Mid_Isle_Manorville_condos_sold_2023.csv
# # Coram_condos_2023_2.csv

# %%
Coram.head(3)
# Out:
#   Air Conditioning  Acres                               Property Description  \
# 0          Central    NaN  Spacious ground floor 1 bedroom Co-op with ope...
# 1          Central    NaN  Up for sale is this beautiful ground level co-...
# 2          Central    NaN  Beautiful 1 Bedroom Deluxe Corner Upper Unit. ...
#
#                    Address      Agency Also For Rent  \
# 0  655 Middle Country Road  Excl Right             N
# 1      237 Pointe Circle N  Excl Right             N
# 2           34 Osage Court  Excl Right             N
#
#                                    Interior Features  Apt# Attic Description  \
# 0  1st Fl Master Bedroom,Granite Countertops,Lr/D...   NaN              None
# 1  1st Fl Master Bedroom,1st Floor Bedrm,Lr/Dr,Pa...   NaN              None
# 2                                                NaN   NaN              None
#
#    Auxiliary Rooms  Baths Full  Baths Half Buyer Agency Compensation  \
# ...

# %%
#Islip.head(1)

# %%
#Patch.head(1)

# %%
#Coram.head(1)

# %% [markdown]
# ## Revise col names

# %%
Coram.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

# %%
Islip.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

# %%
Patch.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

# %%
Ridge.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

# %%
Patch_2.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

# %%
Islip_2.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

# %%
MidIsle_Manor.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

# %%
# Coram_2
Coram_2.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

# %% [markdown]
# ## combine the data

# %%
dataframe_list = [Coram, Islip, Patch, Ridge, Coram_2 ,MidIsle_Manor ,Islip_2, Patch_2]

# %%
condos = pd.concat(dataframe_list , ignore_index=True)

# %%
# Get list of cols

# for column in Coram.columns:
#     print(column)

# %%
# columns_to_select = ['Address', 'Town','Zip','State','Style',
#                      'Development','ML#','Sold_Price','Baths_Full', 'Baths_Half',
#                      'Room_Level','Bath','Bedrooms','Utilities_Included', 'Common_Charges',
#                      'Appearance','REO','Unit_on_Floor_#']

# %%
# Verify Town list

unique_cities = condos['Town'].unique()
unique_cities
# Out:
# array(['Coram', 'Manorville', 'Middle Island', 'Central Islip', 'Islip',
#        'East Islip', 'Patchogue', 'Ridge', 'Bay Shore', 'Selden', nan,
#        'West Islip', 'Islip Terrace', 'East Patchogue'], dtype=object)

# %%
# Lets select some of the columns

# columns_to_select = ['Address', 'Town','Zip','State','Style',
#                      'Development','ML#','Sold_Price','Baths_Full', 'Baths_Half',
#                    'Room_Level','Bath','Bedrooms','Utilities_Included', 'Common_Charges',
#                      'Appearance','REO','Unit_on_Floor_#']

condos = condos[['Address', 'Town','Zip','State','Style',
                     'Development','ML#','Sold_Price','Baths_Full', 'Baths_Half',
                   'Room_Level','Bath','Bedrooms','Utilities_Included', 'Common_Charges',
                     'Appearance','REO','Unit_on_Floor_#']]

# %%
condos.head(3)
# Out:
#                    Address   Town    Zip State             Style  \
# 0  655 Middle Country Road  Coram  11727    NY  Garden Apartment
# 1      237 Pointe Circle N  Coram  11727    NY  Garden Apartment
# 2           34 Osage Court  Coram  11727    NY  Garden Apartment
#
#           Development      ML# Sold_Price  Baths_Full  Baths_Half Room_Level  \
# 0          Les Jardin  3413290     205000           1           0    1,1,1,1
# 1  North Isle Village  3414186     172000           1           0  1,1,1,1,1
# 2  North Isle Village  3414491     150000           1           0    2,2,2,2
#
#    Bath  Bedrooms                                 Utilities_Included  \
# 0   1.0         1  Garbage Removal,Ground Care,Heat,Hot Water,Poo...
# 1   1.0         2  Air Conditioning,Garbage Removal,Gas,Ground Ca...
# 2   1.0         1  Garbage Removal,Gas,Ground Care,Heat,Hot Water...
#
#    Common_Charges Appearance REO Unit_on_Floor_#
# 0             NaN       Mint   N               1
# ...

# %%
condos.shape
# Out:
# (1211, 18)

# %%
# # prompt: in my dataframe find rows that match 'Coram'

# print(condos[condos["Town"] == "Islip_2"])

# %%
# # Using str.contains() to filter rows where the column contains "Mastic"
# #filtered_df = df[df['column_name'].str.contains('Mastic')]
# filtered_df = condos[condos['Town'].str.contains('Ridge')]
# filtered_df

# %%
# Verify Town list

unique_cities = condos['Town'].unique()
unique_cities
# Out:
# array(['Coram', 'Manorville', 'Middle Island', 'Central Islip', 'Islip',
#        'East Islip', 'Patchogue', 'Ridge', 'Bay Shore', 'Selden', nan,
#        'West Islip', 'Islip Terrace', 'East Patchogue'], dtype=object)

# %%
Islip_2.head()
# Out:
#   Air_Conditioning  Acres                               Property_Description  \
# 0          Central    NaN  Welcome home to this beautifully renovated 2 b...
# 1          Central    NaN  Welcome to this Diamond Two Bedroom Two Full B...
# 2       Wall Units    NaN  Why rent when you can own this 2 bedroom, uppe...
# 3          Central    NaN                                                NaN
# 4       Wall Units    NaN  Welcome home to this Mint Condition 2 bedroom ...
#
#            Address       Agency Also_For_Rent  \
# 0  55 Feller Drive  Excl Agency             N
# 1    210 Medea Way   Excl Right             N
# 2    67 Adams Road   Excl Right             N
# 3   24 Bayard Lane  Excl Agency             N
# 4    67 Adams Road   Excl Right             N
#
#                                    Interior_Features  Apt# Attic_Description  \
# 0                               Eat in Kitchen,Lr/Dr   NaN       See Remarks
# ...

# %% [markdown]
# ## R
# emove dupe MLs

# %%
condos.shape
# Out:
# (1211, 18)

# %%
condos = condos.drop_duplicates(subset=['ML#'], keep='first')

# %%
condos.shape
# Out:
# (1115, 18)

# %% [markdown]
# ## Remove Rows that lack a sale price

# %%
# convert SoldPRice to a number
condos['Sold_Price'] = pd.to_numeric(condos['Sold_Price'], errors='coerce')

# %%
condos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1115 entries, 0 to 1210
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Address             1115 non-null   object
#  1   Town                1112 non-null   object
#  2   Zip                 1115 non-null   int64
#  3   State               1115 non-null   object
#  4   Style               1112 non-null   object
#  5   Development         1114 non-null   object
#  6   ML#                 1115 non-null   object
#  7   Sold_Price          1112 non-null   float64
#  8   Baths_Full          1115 non-null   int64
#  9   Baths_Half          1115 non-null   int64
#  10  Room_Level          1106 non-null   object
#  11  Bath                1115 non-null   float64
#  12  Bedrooms            1115 non-null   int64
#  13  Utilities_Included  787 non-null    object
#  14  Common_Charges      850 non-null    float64
# ...

# %%
condos = condos[pd.notna(condos['Sold_Price'])]

# %%
condos.shape
# Out:
# (1112, 18)

# %% [markdown]
# # Geocode

# %% [markdown]
# ## concatenate a new full address column

# %% [markdown]
# ## Add a new column 'country' and fill it with 'USA'

# %%
# Add a new column 'country' and fill it with 'USA'
condos['country'] = 'USA'
# Out:
# <ipython-input-128-4a706ffc9c30>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condos['country'] = 'USA'

# %%
condos['full_address'] = condos['Address'] + ', ' + condos['Town'] + '  '+ condos['country']  # + ', ' + condos['State']
condos.head(3)
# Out:
# <ipython-input-129-6b57a5cf60fb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condos['full_address'] = condos['Address'] + ', ' + condos['Town'] + '  '+ condos['country']  # + ', ' + condos['State']
#                    Address   Town    Zip State             Style  \
# 0  655 Middle Country Road  Coram  11727    NY  Garden Apartment
# 1      237 Pointe Circle N  Coram  11727    NY  Garden Apartment
# 2           34 Osage Court  Coram  11727    NY  Garden Apartment
#
#           Development      ML#  Sold_Price  Baths_Full  Baths_Half Room_Level  \
# 0          Les Jardin  3413290    205000.0           1           0    1,1,1,1
# 1  North Isle Village  3414186    172000.0           1           0  1,1,1,1,1
# ...

# %%
from geopy.exc import GeocoderTimedOut

# ... (previous code)
from geopy.geocoders import Nominatim
import pandas as pd

# Create a GeoPy geocoder
geolocator = Nominatim(user_agent="my_app")



df = condos

# Add columns for longitude and latitude
df["latitude"] = ""
df["longitude"] = ""

# Loop through the dataframe and get the long and lat for each address
for index, row in df.iterrows():
    try:
        location = geolocator.geocode(row["full_address"])
        df.loc[index, "latitude"] = location.latitude
        df.loc[index, "longitude"] = location.longitude
    except:
        df.loc[index, "latitude"] = None
        df.loc[index, "longitude"] = None

# Print the dataframe
print(df)

#

# Loop through the dataframe and get the long and lat for each address
for index, row in df.iterrows():
    try:
        location = geolocator.geocode(row["full_address"])
        df.loc[index, "latitude"] = location.latitude
        df.loc[index, "longitude"] = location.longitude
    except GeocoderTimedOut:
        print(f"Geocoding for address {row['full_address']} timed out.")
        df.loc[index, "latitude"] = None
        df.loc[index, "longitude"] = None
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=237+Pointe+Circle+N%2C+Coram++USA&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=172+Pointe+Circle+N%2C+Coram++USA&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=108+Bailey+Court%2C+Middle+Island++USA&format=json&limit=1
# ...

# %%
# from geopy.geocoders import Nominatim
# import pandas as pd

# # Create a GeoPy geocoder
# geolocator = Nominatim(user_agent="my_app")



# df = condos

# # Add columns for longitude and latitude
# df["latitude"] = ""
# df["longitude"] = ""

# # Loop through the dataframe and get the long and lat for each address
# for index, row in df.iterrows():
#     try:
#         location = geolocator.geocode(row["full_address"])
#         df.loc[index, "latitude"] = location.latitude
#         df.loc[index, "longitude"] = location.longitude
#     except:
#         df.loc[index, "latitude"] = None
#         df.loc[index, "longitude"] = None

# # Print the dataframe
# print(df)

# %%
condos = df

# %%
condos

# %%
condos.shape

# %% [markdown]
# # how many rows came back blank?

# %%
# How many rows are missing lat & long

# Count the number of rows with missing latitude and longitude values
missing_coordinates_count = condos[condos['latitude'].isna() | df['longitude'].isna()].shape[0]

print(f"Number of rows with missing coordinates: {missing_coordinates_count}")

# %% [markdown]
# ## Were some developmets particuarly prone to not coming up with Lat & Long?

# %%
# Assuming 'df' is your DataFrame after geocoding

# Group by 'DEVELOPMENT' and calculate the percentage of missing coordinates
development_percentage_missing = condos.groupby('Development').apply(lambda group: (group['latitude'].isna() | group['longitude'].isna()).mean() * 100)

print(development_percentage_missing)

# %%
import pandas as pd

# Convert the Series to a DataFrame
Pct_missing_df = pd.DataFrame({'Percentage_Missing': development_percentage_missing})

print(Pct_missing_df)

# %%
Pct_missing_df.shape

# %%
# Assuming 'df' is your DataFrame
column_names = Pct_missing_df.columns.tolist()

print(column_names)

# %%
# Move existing index to a new column


df = Pct_missing_df
# Store the original index column
original_index_column = df.index

# Reset the index
df.reset_index(drop=True, inplace=True)

# Add the original index column back as a new column
df['Original_Index'] = original_index_column

print(df)

# %%
# Filter rows where 'Percentage_Missing' is greater than 34
filtered_df = df[df['Percentage_Missing'] > 34]

print(filtered_df)

# %%
# Lets save this list and check mls

#condos.to_csv('condos_sales_2023_geocoded_2.csv' , index=False)
filtered_df.to_csv('DevelopmentsMissingLongLat.csv,index=False')

# %% [markdown]
# ## Export the data as csv

# %%
condos.to_csv('condos_sales_2023_geocoded_2.csv' , index=False)

# %% [markdown]
# ## Drop Rows missing Lat&Long

# %%
condos.shape

# %%
condos_cleaned =  condos.dropna(subset=['latitude', 'longitude'])

# %%
condos_cleaned.shape

# %% [markdown]
# ### Create Safety copy to avoid having to re-geocode

# %%
condos.shape

# %%
#df_cleaned = df.dropna(subset=['latitude', 'longitude'])
condos_cleaned = condos.dropna(subset=['latitude', 'longitude'])
condos_cleaned.shape

# %%
# Lets export and plot in new workbook in Plotly
condos_cleaned.to_csv('condos_cleaned.csv' , index=False)

# %% [markdown]
# # Basement

# %%
t = z

# %%
import geopy.geocoders as geocoders
import pandas as pd

# Create a GeoPy geocoder
geolocator = geocoders.Nominatim(user_agent="my_app")

# Read the dataframe of USA addresses
#df = pd.read_csv("addresses.csv")

df = condos

# Add columns for longitude and latitude
df["latitude"] = ""
df["longitude"] = ""

# Loop through the dataframe and get the long and lat for each address
for index, row in df.iterrows():
    try:
        location = geolocator.geocode(row["full_address"])
        df.loc[index, "latitude"] = location.latitude
        df.loc[index, "longitude"] = location.longitude
    except:
        df.loc[index, "latitude"] = None
        df.loc[index, "longitude"] = None

# Print the dataframe
print(df)

# %%
from geopy.geocoders import Nominatim

# Create a Nominatim geocoder object with a user agent
geolocator = Nominatim(user_agent="myGeocoder")

# Sample addresses (replace with your addresses)
addresses = [
    "1600 Amphitheatre Parkway, Mountain View, CA",
    "1 Microsoft Way, Redmond, WA",
    "350 5th Ave, New York, NY"
]

# Geocode addresses
for address in addresses:
    location = geolocator.geocode(address)
    if location:
        print("Address:", address)
        print("Latitude:", location.latitude)
        print("Longitude:", location.longitude)
        print()
    else:
        print("Geocoding failed for:", address)
        print()

# %%
df = pd.read_csv('/content/addresses.csv')
df.head()

# %%
from geopy.extra.rate_limiter import RateLimiter

# 1 - conveneint function to delay between geocoding calls
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)
# 2- - create location column
df['location'] = df['ADDRESS'].apply(geocode)
# 3 - create longitude, laatitude and altitude from location column (returns tuple)
df['point'] = df['location'].apply(lambda loc: tuple(loc.point) if loc else None)
# 4 - split point column into latitude, longitude and altitude columns
df[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df['point'].tolist(), index=df.index)

# %%
# https://towardsdatascience.com/geocode-with-python-161ec1e62b89

# from geopy.extra.rate_limiter import RateLimiter

# # 1 - conveneint function to delay between geocoding calls
# geocode = RateLimiter(locator.geocode, min_delay_seconds=1)
# # 2- - create location column
# df['location'] = df['ADDRESS'].apply(geocode)
# # 3 - create longitude, laatitude and altitude from location column (returns tuple)
# df['point'] = df['location'].apply(lambda loc: tuple(loc.point) if loc else None)
# # 4 - split point column into latitude, longitude and altitude columns
# df[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df['point'].tolist(), index=df.index)

# %%
df = condos

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent="my_geocoder")

# %%
location = geolocator.geocode("175 5th Avenue NYc")

# %%
print(location.address)

# %%
print((location.latitude, location.longitude))
